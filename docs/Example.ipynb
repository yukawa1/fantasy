# %% [markdown]
# # Example

# %%
from fantasy.tools import read_sdss, read_text

# %% [markdown]
# Firstly, let us read spectrum. `Spectra` class has three methods: `read_sdss` , `read_gama_fits` and `read_txt`. `read_sdss` is designed to read SDSS spectra, while `read_text` ASCII files.
#
# It is possible to read any format of spectra using any prefered method, and convert it to spectral class used in the FANTASY using `make_spec`...

# %%
from fantasy.models import automatic_path, FeII, create_model, create_tied_model, continuum, create_line, create_fixed_model, create_input_folder, create_feii_model, Bal_Lines, BalCon, UV_FeII

# %%
s=read_text('/home/yukawa/Downloads/2016ezh_2016-08-26_02-20-39_Ekar_AFOSC_None.txt')

# %%
s.ra=29.519807539582
s.dec=-0.872742349310271

# %%
s.DeRedden()

# %%
s.z=0.0804

# %%
s.CorRed()

# %%
s.flux=s.flux*10**16

# %%
s.crop(3000, 7000)

# %% [markdown]
# For bulk spectra fitting, for automatic path of input files `use automatic_path(s)`

# %%
create_input_folder(xmin=3000,xmax=7000, path_to_folder='/home/yukawa/Downloads/fitting/tde/', overwrite=True)
# Out:
# Directory  /home/yukawa/Downloads/fitting/tde/  already exists

# %% [markdown]
# `continuum()` calls `BrokenPowerlaw()` model with defining amplitude of the continuum from given spectra

# %%
cont=continuum(s,min_refer=5790, refer=5800, max_refer=5810)

broad=create_fixed_model(['hydrogen.csv', 'helium.csv'], name='br')
br_other=create_model(['broad.csv'], prefix='br')
fe_fixed=create_fixed_model(['feII_forbidden.csv'], name='fe_forr', fwhm=300,max_fwhm=1600)

narrow=create_tied_model(name='OIII5007',files=['narrow_basic.csv','narrow_plus.csv','hydrogen.csv', 'helium.csv'
                                               ],prefix='nr',min_amplitude=.1, fwhm=300,min_offset=-300, max_offset=3000, min_fwhm=100, max_fwhm=1200)
fe=create_feii_model()
fe_nar=create_feii_model('naffFe',min_fwhm=100, max_fwhm=1500)
bl=Bal_Lines()
bc=BalCon()
uv=UV_FeII()
# Out:
# WARNING: parameter naffFe.fwhm greater than new maximum; naffFe.fwhm reset to 1500

# %%
model =cont+narrow+broad+fe+fe_fixed+fe_nar+br_other+bl+bc+uv

# %%
s.fit(model, ntrial=1)
# Out:
# stati 16014.730536571673

# %%
import matplotlib.pyplot as plt
import matplotlib as mpl
from matplotlib.ticker import (MultipleLocator, FormatStrFormatter, AutoMinorLocator)

# %%
plt.style.context(['nature', 'notebook'])
plt.figure(figsize=(18,6))
plt.plot(s.wave, s.flux)
plt.plot(s.wave, model(s.wave))
plt.plot(s.wave, model(s.wave)-s.flux)

plt.plot(s.wave, cont(s.wave))
plt.plot(s.wave, narrow(s.wave))
plt.plot(s.wave, broad(s.wave))
plt.plot(s.wave, fe(s.wave))
plt.plot(s.wave, fe_fixed(s.wave))
plt.plot(s.wave, fe_nar(s.wave))

plt.plot(s.wave, (bl+bc)(s.wave))
plt.xlabel('Rest Wavelength')
plt.ylabel('Flux')
plt.tick_params(which='both', direction="in")
#plt.plot(s.)
plt.savefig('/home/yukawa/slika.pdf')

# %%
model
# Out:
# <BinaryOpModel model instance '(((((((((brokenpowerlaw + ((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((nr_OIII5007 + nr_OIII4958) + nr_NII6584) + nr_NIII6548) + nr_[O II]_3726) + nr_[O II]_3728) + nr_[Ne III]_3868) + nr_[O III]_4363) + nr_[O I]_6300) + nr_[O I]_6363) + nr_[S II]_6716) + nr_[S II]_6730) + nr_[O II]_3726) + nr_[O II]_3728) + nr_[Ne III]_3868) + nr_Cr II 194_4003) + nr_Ni II 12_4015) + nr_Ti II 87_4053) + nr_Cr II 19_4063) + nr_[S II] 1F_4068) + nr_[S II] 1F_4076) + nr_N III_4097) + nr_NIII_4103) + nr_Ti II 105_4163) + nr_Ti II 19_4395) + nr_O II_4414) + nr_Ti II 93_4421) + nr_Ti II 19_4443) + nr_Ti II 19_4450) + nr_NIII1_4510) + nr_Cr II 44_4616) + nr_N III_4640) + nr_N II 5_4643) + nr_C III_4647) + nr_C III_4650) + nr_C III_4651) + nr_Cr II_4697) + nr_Cr II 30_4824) + nr_Cr II 30_4876) + nr_Ti II 114_4911) + nr_Ti II 113_5072) + nr_[N I]_5200) + nr_C III_5695) + nr_Si II_5957) + nr_OIb_6046) + nr_S II_6288) + nr_[S III]_6312) + nr_Si II_6347) + nr_Si II_6371) + nr_Heps_3970) + nr_Hd_4101) + nr_Hg_4340) + nr_Hb_4861) + nr_Ha_6562) + nr_HeI_3187) + nr_HeII_3203) + nr_HeI_4143) + nr_HeI_4471) + nr_HeII_4685) + nr_HeI_5877) + nr_HeI_6680)) + br) + feii) + fe_forr) + naffFe) + (((0.0 + br_NaI_5890) + br_NaI1_5896) + br_OI_6046)) + Bal_lines) + BalCon) + uv_feii)'>

# %%
s.gres.parnames
# Out:
# ('brokenpowerlaw.refer',
#  'brokenpowerlaw.ampl',
#  'brokenpowerlaw.index1',
#  'brokenpowerlaw.index2',
#  'nr_OIII5007.ampl',
#  'nr_OIII5007.offs_kms',
#  'nr_OIII5007.fwhm',
#  'nr_NII6584.ampl',
#  'nr_[O II]_3726.ampl',
#  'nr_[O II]_3728.ampl',
#  'nr_[Ne III]_3868.ampl',
#  'nr_[O III]_4363.ampl',
#  'nr_[O I]_6300.ampl',
#  'nr_[O I]_6363.ampl',
#  'nr_[S II]_6716.ampl',
#  'nr_[S II]_6730.ampl',
#  'nr_[O II]_3726.ampl',
#  'nr_[O II]_3728.ampl',
#  'nr_[Ne III]_3868.ampl',
#  'nr_Cr II 194_4003.ampl',
#  'nr_Ni II 12_4015.ampl',
#  'nr_Ti II 87_4053.ampl',
#  'nr_Cr II 19_4063.ampl',
#  'nr_[S II] 1F_4068.ampl',
#  'nr_[S II] 1F_4076.ampl',
#  'nr_N III_4097.ampl',
#  'nr_NIII_4103.ampl',
#  'nr_Ti II 105_4163.ampl',
#  'nr_Ti II 19_4395.ampl',
#  'nr_O II_4414.ampl',
#  'nr_Ti II 93_4421.ampl',
#  'nr_Ti II 19_4443.ampl',
#  'nr_Ti II 19_4450.ampl',
#  'nr_NIII1_4510.ampl',
#  'nr_Cr II 44_4616.ampl',
#  'nr_N III_4640.ampl',
#  'nr_N II 5_4643.ampl',
#  'nr_C III_4647.ampl',
#  'nr_C III_4650.ampl',
#  'nr_C III_4651.ampl',
#  'nr_Cr II_4697.ampl',
#  'nr_Cr II 30_4824.ampl',
#  'nr_Cr II 30_4876.ampl',
#  'nr_Ti II 114_4911.ampl',
#  'nr_Ti II 113_5072.ampl',
#  'nr_[N I]_5200.ampl',
#  'nr_C III_5695.ampl',
#  'nr_Si II_5957.ampl',
#  'nr_OIb_6046.ampl',
#  'nr_S II_6288.ampl',
#  'nr_[S III]_6312.ampl',
#  'nr_Si II_6347.ampl',
#  'nr_Si II_6371.ampl',
#  'nr_Heps_3970.ampl',
#  'nr_Hd_4101.ampl',
#  'nr_Hg_4340.ampl',
#  'nr_Hb_4861.ampl',
#  'nr_Ha_6562.ampl',
#  'nr_HeI_3187.ampl',
#  'nr_HeII_3203.ampl',
#  'nr_HeI_4143.ampl',
#  'nr_HeI_4471.ampl',
#  'nr_HeII_4685.ampl',
#  'nr_HeI_5877.ampl',
#  'nr_HeI_6680.ampl',
#  'br.amp_Heps_3970',
#  'br.amp_Hd_4102',
#  'br.amp_Hg_4340',
#  'br.amp_Hb_4861',
#  'br.amp_Ha_6563',
#  'br.amp_HeI_3188',
#  'br.amp_HeII_3203',
#  'br.amp_HeI_4144',
#  'br.amp_HeI_4471',
#  'br.amp_HeII_4686',
#  'br.amp_HeI_5877',
#  'br.amp_HeI_6680',
#  'br.offs_kms',
#  'br.fwhm',
#  'feii.amp_z4F',
#  'feii.amp_z4D',
#  'feii.amp_a4G',
#  'feii.amp_a4H',
#  'feii.amp_b2H',
#  'feii.amp_b4D',
#  'feii.amp_b4F',
#  'feii.amp_b4P',
#  'feii.amp_a6S',
#  'feii.amp_a2D2',
#  'feii.offs_kms',
#  'feii.fwhm',
#  'fe_forr.amp_[Fe II] 23F_4114',
#  'fe_forr.amp_[Fe II] 21F_4147',
#  'fe_forr.amp_[Fe II] 21F_4177',
#  'fe_forr.amp_[Fe II] 23F_4179',
#  'fe_forr.amp_[Fe II] 21F_4232',
#  'fe_forr.amp_[Fe II] 21F_4244',
#  'fe_forr.amp_[Fe II] 21F_4245',
#  'fe_forr.amp_[Fe II] 23F_4251',
#  'fe_forr.amp_[Fe II] 21F_4277',
#  'fe_forr.amp_[Fe II] 7F_4287',
#  'fe_forr.amp_[Fe II] 21F_4306',
#  'fe_forr.amp_[Fe II] 21F_4320',
#  'fe_forr.amp_[Fe II] 21F_4347',
#  'fe_forr.amp_[Fe II] 21F_4353',
#  'fe_forr.amp_[Fe II] 21F_4358',
#  'fe_forr.amp_[Fe II] 7F_4359',
#  'fe_forr.amp_[Fe II] 21F_4372',
#  'fe_forr.amp_[Fe II] 6F_4383',
#  'fe_forr.amp_[Fe II] 7F_4414',
#  'fe_forr.amp_[Fe II] 6F_4416',
#  'fe_forr.amp_[Fe II] 6F_4432',
#  'fe_forr.amp_[Fe II] 7F_4452',
#  'fe_forr.amp_[Fe II] 6F_4458',
#  'fe_forr.amp_[Fe II] 7F_4475',
#  'fe_forr.amp_[Fe II] 6F_4489',
#  'fe_forr.amp_[Fe II] 6F_4493',
#  'fe_forr.amp_[Fe II] 6F_4528',
#  'fe_forr.amp_[Fe II] 4F_4640',
#  'fe_forr.amp_[Fe II] 4F_4664',
#  'fe_forr.amp_[Fe II] 4F_4728',
#  'fe_forr.amp_[Fe II] 20F_4775',
#  'fe_forr.amp_[Fe II] 4F_4798',
#  'fe_forr.amp_[Fe II] 20F_4815',
#  'fe_forr.amp_[Fe II] 20F_4874',
#  'fe_forr.amp_[Fe II] 4F_4890',
#  'fe_forr.amp_[Fe II]_4899',
#  'fe_forr.amp_[Fe II] 20F_4905',
#  'fe_forr.amp_[Fe II] 20F_4947',
#  'fe_forr.amp_[Fe II] 20F_4951',
#  'fe_forr.amp_[Fe II] 20F_4973',
#  'fe_forr.amp_[Fe II] 20F_5006',
#  'fe_forr.amp_[Fe II] 20F_5020',
#  'fe_forr.amp_[Fe II] 20F_5044',
#  'fe_forr.amp_[Fe II]_5060',
#  'fe_forr.amp_[Fe II] 19F_5072',
#  'fe_forr.amp_[Fe II] 18F_5108',
#  'fe_forr.amp_[Fe II] 19F_5112',
#  'fe_forr.amp_[Fe II] 18F_5158',
#  'fe_forr.amp_[Fe II] 19F_5159',
#  'fe_forr.amp_[Fe II] 18F_5182',
#  'fe_forr.amp_[Fe II] 19F_5185',
#  'fe_forr.amp_[Fe II] 19F_5220',
#  'fe_forr.amp_[Fe II] 19F_5262',
#  'fe_forr.amp_[Fe II] 18F_5269',
#  'fe_forr.amp_[Fe II] 18F_5273',
#  'fe_forr.amp_[Fe II] 19F_5297',
#  'fe_forr.amp_[Fe II] 19F_5334',
#  'fe_forr.amp_[Fe II] 18F_5348',
#  'fe_forr.amp_[Fe II] 19F_5376',
#  'fe_forr.amp_[Fe II] 17F_5413',
#  'fe_forr.amp_[Fe II] 18F_5433',
#  'fe_forr.amp_[Fe II] 34F_5477',
#  'fe_forr.amp_[Fe II] 17F_5496',
#  'fe_forr.amp_[Fe II] 17F_5527',
#  'fe_forr.amp_[Fe II] 34F_5528',
#  'fe_forr.amp_[Fe II] 18F_5556',
#  'fe_forr.amp_[Fe II] 34F_5747',
#  'fe_forr.offs_kms',
#  'fe_forr.fwhm',
#  'naffFe.amp_z4F',
#  'naffFe.amp_z4D',
#  'naffFe.amp_a4G',
#  'naffFe.amp_a4H',
#  'naffFe.amp_b2H',
#  'naffFe.amp_b4D',
#  'naffFe.amp_b4F',
#  'naffFe.amp_b4P',
#  'naffFe.amp_a6S',
#  'naffFe.amp_a2D2',
#  'naffFe.offs_kms',
#  'naffFe.fwhm',
#  'br_NaI_5890.ampl',
#  'br_NaI_5890.offs_kms',
#  'br_NaI_5890.fwhm',
#  'br_NaI1_5896.ampl',
#  'br_NaI1_5896.offs_kms',
#  'br_NaI1_5896.fwhm',
#  'br_OI_6046.ampl',
#  'br_OI_6046.offs_kms',
#  'br_OI_6046.fwhm',
#  'Bal_lines.ampl',
#  'Bal_lines.offs_kms',
#  'Bal_lines.fwhm',
#  'BalCon.A',
#  'BalCon.T',
#  'BalCon.tau',
#  'uv_feii.amp_uv_fe_78',
#  'uv_feii.offs_kms',
#  'uv_feii.fwhm')

# %%
s.save_json()

# %%
import plotly.express as px

# %%
s1=read_text('/home/yukawa/Documents/tde/SN2016ezh20161222_photcal_V.txt')

# %%
import plotly.graph_objects as go

# %%
import plotly.graph_objects as go
fig=go.Figure()
fig.add_trace(go.Scatter(x=s.wave, y=s.flux,mode='lines',name='prvi spektar'))
fig.add_trace(go.Scatter(x=s1.wave, y=s1.flux*10**15, mode='lines', name='drugi spektar'))

# %%
import pandas as pd
d={'cont':cont(s.wave), 'broad':broad(s.wave), 'fe_forb':fe_forb(s.wave), 'narrow':narrow(s.wave), 'fe_nar':fe_nar(s.wave), 'fe':fe(s.wave)}
df=pd.DataFrame(d)
df.to_csv('naziv_fajla.csv')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_14342/3024911709.py in <module>
#       1 import pandas as pd
# ----> 2 d={'cont':cont(s.wave), 'broad':broad(s.wave), 'fe_forb':fe_forb(s.wave), 'narrow':narrow(s.wave), 'fe_nar':fe_nar(s.wave), 'fe':fe(s.wave)}
#       3 df=pd.DataFrame(d)
#       4 df.to_csv('naziv_fajla.csv')
#
# NameError: name 'fe_forb' is not defined
